# %%
# %load_ext Cython
# %matplotlib inline
import numpy as np 
import matplotlib.pyplot as plt  
from scipy.ndimage import rotate

# %%
def low_pass_filter(img):
    n0, n1 = img.shape

    x, y = np.mgrid[0:n0, 0:n1]
    x -= n0//2
    y -= n1//2
    r = np.sqrt(x*x + y*y)

    fil = np.fft.ifftshift(np.where(r < min(n0, n1)/3, 1, 0))

    filtered_img = np.fft.ifft2( np.fft.fft2(img) * fil ).real
    return filtered_img

def slices_gen(img, thetas):
    l_max = np.max(img.shape)
    slices = np.zeros([len(thetas), l_max], dtype = np.float64)
    for i, theta in enumerate(thetas):
        rotated_img = rotate(img, -theta, reshape = False, prefilter = True)
        mid = rotated_img[rotated_img.shape[0]//2, :]
        pad_width = [int(np.floor(l_max - len(mid))/2.), int(np.ceil((l_max - len(mid))/2.))]
        mid = np.pad(mid, pad_width, mode = "constant", constant_values = 0)
        slices[i] = mid
    return slices

def radon(img, thetas):
    l_max = np.max(img.shape)
    sinogram = np.zeros([len(thetas), l_max], dtype = np.float64)
    for i, theta in enumerate(thetas):
        rotated_img = rotate(img, -theta, reshape = False, prefilter = True)
        proj = np.sum(rotated_img, axis = 0)
        pad_width = [int(np.floor(l_max - len(proj))/2.), int(np.ceil((l_max - len(proj))/2.))]
        proj = np.pad(proj, pad_width, mode = "constant", constant_values = 0)
        sinogram[i] = proj
    return sinogram.T

def iradon(sinogram, thetas):
    n0, n1 = sinogram.shape
    assert(n1 == len(thetas))
    thetas = thetas / 180 * np.pi
    fil = np.abs(np.fft.fftfreq(n0)).reshape((-1, 1))
    filtered_sino = np.fft.ifft(np.fft.fft(sinogram, axis = 0) * fil, axis = 0).real

    x, y = np.mgrid[0:n0,0:n0]
    x -= n0//2
    y -= n0//2
    t = np.arange(n0) - n0//2

    recon = np.zeros([n0,n0], dtype = np.float64)
    for i,theta in enumerate(thetas):
        tt = -x*np.sin(theta) + y*np.cos(theta)
        back_proj = np.interp(tt, t, filtered_sino[:, i])
        recon += back_proj
    return recon

def recon_ftm(sinogram, thetas):
    thetas = np.pi/2 + thetas/180. * np.pi
    N, M = sinogram.shape
    ft_sinogram = np.fft.fftshift(np.fft.fft(sinogram, axis=0), axes=0)
    model = np.zeros((N,N), dtype = np.complex128)
    dth = thetas[1] - thetas[0]
    df = 1./N
    
    freq = np.fft.fftshift(np.fft.fftfreq(N))
    th, f = np.meshgrid(thetas, freq)
    fx = f*np.cos(th)
    fy = f*np.sin(th)
    
    ffx, ffy = np.meshgrid(freq, freq)
    
    for i in range(N):
        for j in range(N):
            u = (i-N//2)*df
            v = (j-N//2)*df
            kernel = np.sinc((u-fx)/df)*np.sinc((v-fy)/df)*np.abs(f)
            model[i,j] = df*dth*np.sum(kernel * ft_sinogram)
    return model

def pad_img(img):
    s0, s1 = img.shape
    diagonal = int(np.ceil(np.sqrt(3) * np.max([s0,s1])))
    oc0 = s0//2
    oc1 = s1//2
    pad0 = diagonal - s0
    pad1 = diagonal - s1
    nc0 = (pad0 + s0)//2
    nc1 = (pad1 + s1)//2
    trans0 = nc0 - oc0
    trans1 = nc1 - oc1

    pad_width = np.array([[ trans0, pad0 - trans0 ],
                          [ trans1, pad1 - trans1 ]], dtype = np.int32)
    padded_img = np.pad(img, pad_width, mode = "constant", constant_values = 0)

    return padded_img

# %%
phantom = np.load("phantom_small.npy")
# X, Y = np.mgrid[-5*np.pi:5*np.pi:256*1j, -5*np.pi:5*np.pi:256*1j]
# y1 = np.sin(X) + np.sin(3*X)
# y2 = np.sin(X+Y) + np.sin(3*X+3*Y)
# y3 = np.sin(-X+Y) + np.sin(-3*X + 3*Y)
# y4 = np.sin(Y) + np.sin(3*Y)
# phantom = y1+y2+y3+y4
phantom = pad_img(phantom)
phantom = np.pad(phantom, pad_width = [[0,1],[0,1]], mode="constant", constant_values = 0)
plt.imshow(phantom, cmap=plt.cm.Greys_r)
thetas = np.arange(0,180, dtype = np.float64)
phantom = low_pass_filter(phantom)
ft_phantom = np.fft.fftshift(np.fft.fft2(phantom))

# %%
thetas = np.arange(0,180,1, dtype=np.float64)
sinogram = radon(phantom, thetas)
ft_sinogram = np.fft.fftshift(np.fft.fft(sinogram, axis=0), axes=0)

recon1 = iradon(sinogram, thetas)

# %%
plt.imshow(sinogram, cmap = plt.cm.Greys_r)
plt.xlabel("theta")
plt.title("sinogram")
# plt.savefig("/Users/xinchen/myblog/assets/img/ct/sinogram.png")

# %%
model = recon_ftm(sinogram, thetas)

# %%
fig, (ax1, ax2) = plt.subplots(ncols = 2)
ax1.imshow(np.abs(ft_phantom), cmap = plt.cm.Greys)
ax2.imshow(np.abs(model), cmap = plt.cm.Greys)

# %%
recon4 = np.fft.ifft2(np.fft.ifftshift(model)).real
plt.imshow(recon4)

# %%
imgs = [phantom, sinogram, np.abs(ft_sinogram), model.real]
titles = ["original", "sinogram", "sinogram FFT", "FTM recon"]

fig, axes = plt.subplots(ncols = len(imgs), figsize = [14, 5])

for i, ax in enumerate(axes):
    ax.imshow(imgs[i], cmap = plt.cm.Greys_r)
    ax.set_title(titles[i])
#     ax.set_yticks([])
plt.savefig("/Users/xinchen/Desktop/shown2.png")

# %%
plt.imshow(recon4, cmap=plt.cm.Greys_r)
plt.savefig("/Users/xinchen/Desktop/recon.png")

# %%
slices_real = slices_gen(ft_phantom.real, thetas)
slices_imag = slices_gen(ft_phantom.imag, thetas)
ft_sinogram_r = slices_real + 1j * slices_imag
ft_sinogram_r = ft_sinogram_r.T

# %%
err = ft_sinogram - ft_sinogram_r
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(nrows = 2, ncols = 2, sharex=True, sharey=False)
ax1.imshow(ft_sinogram.real, cmap = plt.cm.Greys_r)
ax2.imshow(ft_sinogram_r.real, cmap = plt.cm.Greys_r)
# ax3.imshow(err.real)
ax1.set_title("FT sinogram")
ax2.set_title("central slices of 2D FT")
ax3.set_xlabel("theta")
ax4.set_xlabel("theta")
ax1.text(-40,75,"real")

ax3.imshow(ft_sinogram.imag, cmap = plt.cm.Greys_r)
ax4.imshow(ft_sinogram_r.imag, cmap = plt.cm.Greys_r)
ax3.text(-40,75,"imag")
ax1.set_yticks([])
# ax2.set_yticks([])
ax3.set_yticks([])
# ax4.set_yticks([])


plt.savefig("/Users/xinchen/myblog/assets/img/ct/FT_sino_compare.png")

# %%
err = ft_sinogram - ft_sinogram_r
fig, (ax1, ax2, ax3) = plt.subplots(ncols=3)
ax1.plot(ft_sinogram[:,10].real)
ax2.plot(ft_sinogram_r[:,10].real)
ax3.plot(err[:,10].real)

# %%
cors = []
for i in range(len(thetas)):
    x1 = ft_sinogram[:,i]
    x2 = ft_sinogram_r[:,i]
    d1 = np.sqrt(np.sum(np.abs(x1)**2))
    d2 = np.sqrt(np.sum(np.abs(x2)**2))
    cors.append(np.correlate(x1, x2)/(d1*d2) )

# %%
plt.plot(thetas, np.abs(cors))
# plt.plot([90,90],[0.79,np.abs(cors)[90]], "k-.", linewidth=1)
# plt.plot([37,37],[0.79,np.abs(cors)[37]], "k-.", linewidth=1)

plt.xlabel("theta")
plt.ylabel("correlation")
# plt.savefig("/Users/xinchen/myblog/assets/img/ct/correlation.png")

# %%
plt.plot(ft_sinogram.real[:,0])

# %%
plt.plot(ft_sinogram_r.real[:,0]/1000)

# %%
plt.imshow(model.real)

# %%
re = np.fft.ifft2(np.fft.ifftshift(model)).real

# %%
plt.imshow(re)

# %%
plt.plot(ft_sinogram_r[:,0].imag)

# %%
plt.plot(ft_sinogram[:,0].imag)
